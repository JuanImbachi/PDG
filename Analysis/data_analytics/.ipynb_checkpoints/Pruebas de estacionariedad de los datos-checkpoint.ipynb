# %% [markdown]
# # Reporte analítica de datos - Proyecto de Grado II

# %% [markdown]
# ## Preparación de los datos

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller
from pandas.plotting import autocorrelation_plot
from matplotlib import pyplot
from pandas import DataFrame
from pandas import concat
from pandas.plotting import lag_plot
from statsmodels.tsa.ar_model import AutoReg
from statsmodels.graphics.tsaplots import plot_pacf
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.arima_model import ARIMA
import datetime as datetime

# %%
data = pd.read_csv('../dengue_data/Data.csv')
df = pd.DataFrame(data)
df["Date"] = pd.to_datetime(df['Date'])
df['Age'] = df['Age'].astype(float)
df.set_index('Id', inplace=True)
df.head(10)
# Out:
#     City       Date   Age Gender Neighborhood  Commune
# Id
# 1   Buga 2010-01-14  23.0      F    LA MERCED        4
# 2   Buga 2010-01-11  23.0      F   EL CARMELO        6
# 3   Buga 2010-01-10  20.0      M   EL CARMELO        6
# 4   Buga 2010-01-12   6.0      F        SUCRE        3
# 5   Buga 2010-01-07  13.0      M      POPULAR        5
# 6   Buga 2010-03-08  20.0      M  DIVINO NINO        3
# 7   Buga 2010-03-13  18.0      F  DIVINO NINO        3
# 8   Buga 2010-03-07  36.0      M  ALTO BONITO        1
# 9   Buga 2010-03-15  40.0      M    EL JARDIN        5
# 10  Buga 2010-03-08  25.0      F   VALLE REAL        3

# %% [markdown]
# ## Pruebas de hipóstesis para determinar si las series de tiempo son estacionarias | DICKEY-FULLER TEST
#
# **Hipótesis nula:** La serie de tiempo no es estacionaria
#
# **Hipótesis del investigador:** La serie de tiempo es estacionaria
#
# *Si el estadístico ADF < Valor crítico entonces rechazo la hipótesis nula*
# *Si el estadístico ADF > Valor crítico entonces acepto la hipótesis nula*

# %% [markdown]
# **Se trabajarán las series de tiempo individuales por barrios entre los años 2013 y 2016**

# %%
data_model = pd.DataFrame(df['FecNot'].value_counts().sort_index())
data_model.columns = ['Casos']
data_model.index.name = 'Fecha'

# %%
df
# Out:
#          Id MesOcurrencia     FecNot  Semana   Ano Edad GrupoEdad Sexo  \
# 0       156         enero 2010-01-14       1  2010   23   15 - 44    F
# 1       157         enero 2010-11-01       1  2010   23   15 - 44    F
# 2       158         enero 2010-10-01       1  2010   20   15 - 44    M
# 3       161         enero 2010-12-01       1  2010    6    5 - 14    F
# 4       162         enero 2010-07-01       1  2010   13    5 - 14    M
# ...     ...           ...        ...     ...   ...  ...       ...  ...
# 3032  54384          mayo 2018-05-29      21  2018   39   15 - 44    F
# 3033  54386       febrero 2018-02-19       7  2018   48   45 - 60    M
# 3034  54387         marzo 2018-03-24       9  2018   31   15 - 44    F
# 3035  54388         marzo 2018-05-03       9  2018   62      > 60    M
# 3036  54390         marzo 2018-08-04      13  2018   29   15 - 44    M
#
#              Barrio  Comuna
# 0         LA MERCED       4
# 1        EL CARMELO       6
# 2        EL CARMELO       6
# 3             SUCRE       3
# 4           POPULAR       5
# ...             ...     ...
# 3032    EL ALBERGUE       6
# 3033    SAN ANTONIO       2
# 3034     VALLE REAL       3
# 3035    EL ALBERGUE       6
# 3036  SANTA BARBARA       2
#
# [3037 rows x 10 columns]

# %%
def stationarity_analysis_nb(nb_df, name):
    results = adfuller(nb_df)
    print('Estadístico ADF: %f' % results[0])
    print('p-value: %f' % results[1])
    print('Valor crítico:')
    for key,value in results[4].items():
        print('\t%s: %.3f'% (key,value))

    if results[0] < results[4]["5%"] :
        print("Rechazo Ho: La serie de tiempo es estacionaria")
        nb_df.plot(kind='line', figsize=(30,5))
        plt.title(name)  
        plt.ylabel("Número de casos")    
    else :
        print("Acepta Ho: La serie de tiempo no es estacionaria\n\nDebido a que la serie de tiempo no es estacionaria se procede a transformarla:\n")
        nb_df = nb_df.diff().dropna()
        results = adfuller(nb_df)
        print('Estadístico ADF: %f' % results[0])
        print('p-value: %f' % results[1])
        print('Valor crítico:')
        for key,value in results[4].items():
            print('\t%s: %.3f'% (key,value))

        if results[0] < results[4]["5%"] :
            print("Rechazo Ho: La serie de tiempo es estacionaria")
        else :
            print("Acepta Ho: La serie de tiempo no es estacionaria")

        nb_df.plot(kind='bar')

# %%
def assign_zeros(nb_df) :
    day_delta = datetime.timedelta(days=1)
    start_date = datetime.date(2013, 1, 1)
    end_date = datetime.date(2017, 1, 1)

    list = []

    for i in range((end_date - start_date).days):
        date = start_date + i*day_delta
        try: 
            list.append(nb_df.at[date,'Casos'])
        except:  
            list.append(0)
            
    final_model = pd.DataFrame(columns=('Fecha', 'Casos'))

    for i in range((end_date - start_date).days):
        date = start_date + i*day_delta
        final_model.loc[len(final_model)]=[date, list[i]]
        
    return final_model

# %% [markdown]
# Se completan los registros (1461) entre los años 2010 y 2018. El día donde no haya un acaso se agrega con un 0.
#
# **Después para cada barrio se hace su respectivo análisis de estacionariedad**

# %%
neighborhoods_df = df['Barrio'].value_counts().sort_index()

for neighborhood_name in neighborhoods_df.index :
    nb_df = df[df.Barrio == neighborhood_name]
    h = pd.DataFrame(nb_df['FecNot'].value_counts().sort_index())
    h.columns = ['Casos']
    h.index.name = 'Fecha'
    df_zeros = assign_zeros(h)
    df_zeros.set_index('Fecha',inplace=True)
    stationarity_analysis_nb(df_zeros,neighborhood_name)
# Out:
# Estadístico ADF: -38.277997
# p-value: 0.000000
# Valor crítico:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# Rechazo Ho: La serie de tiempo es estacionaria
# Estadístico ADF: -38.370018
# p-value: 0.000000
# Valor crítico:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# Rechazo Ho: La serie de tiempo es estacionaria
# Estadístico ADF: -13.927424
# p-value: 0.000000
# Valor crítico:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# Rechazo Ho: La serie de tiempo es estacionaria
# Estadístico ADF: -17.495741
# p-value: 0.000000
# Valor crítico:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# Rechazo Ho: La serie de tiempo es estacionaria
# Estadístico ADF: -37.280059
# p-value: 0.000000
# Valor crítico:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# Rechazo Ho: La serie de tiempo es estacionaria
# Estadístico ADF: -16.723481
# p-value: 0.000000
# Valor crítico:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# Rechazo Ho: La serie de tiempo es estacionaria
# Estadístico ADF: -14.365315
# p-value: 0.000000
# Valor crítico:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# Rechazo Ho: La serie de tiempo es estacionaria
# Estadístico ADF: -17.996546
# p-value: 0.000000
# Valor crítico:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# Rechazo Ho: La serie de tiempo es estacionaria
# Estadístico ADF: -38.448017
# p-value: 0.000000
# Valor crítico:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# Rechazo Ho: La serie de tiempo es estacionaria
# Estadístico ADF: -17.691417
# p-value: 0.000000
# Valor crítico:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# Rechazo Ho: La serie de tiempo es estacionaria
# Estadístico ADF: -37.058183
# p-value: 0.000000
# Valor crítico:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# Rechazo Ho: La serie de tiempo es estacionaria
# Estadístico ADF: -38.031037
# p-value: 0.000000
# Valor crítico:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# Rechazo Ho: La serie de tiempo es estacionaria
# Estadístico ADF: -6.643030
# p-value: 0.000000
# Valor crítico:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# Rechazo Ho: La serie de tiempo es estacionaria
# Estadístico ADF: -38.717831
# p-value: 0.000000
# Valor crítico:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# Rechazo Ho: La serie de tiempo es estacionaria
# Estadístico ADF: -38.288811
# p-value: 0.000000
# Valor crítico:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# Rechazo Ho: La serie de tiempo es estacionaria
# Estadístico ADF: -38.551856
# p-value: 0.000000
# Valor crítico:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# Rechazo Ho: La serie de tiempo es estacionaria
# Estadístico ADF: -37.379069
# p-value: 0.000000
# Valor crítico:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# Rechazo Ho: La serie de tiempo es estacionaria
# Estadístico ADF: -38.799889
# p-value: 0.000000
# Valor crítico:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# Rechazo Ho: La serie de tiempo es estacionaria
# Estadístico ADF: -13.006944
# p-value: 0.000000
# Valor crítico:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# Rechazo Ho: La serie de tiempo es estacionaria
# Estadístico ADF: -38.968953
# p-value: 0.000000
# Valor crítico:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# Rechazo Ho: La serie de tiempo es estacionaria
# Estadístico ADF: -19.384504
# p-value: 0.000000
# Valor crítico:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# Rechazo Ho: La serie de tiempo es estacionaria
# /Users/jorge/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:320: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# Estadístico ADF: -13.679424
# p-value: 0.000000
# Valor crítico:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# Rechazo Ho: La serie de tiempo es estacionaria
# /Users/jorge/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:320: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# Estadístico ADF: -36.783058
# p-value: 0.000000
# Valor crítico:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# Rechazo Ho: La serie de tiempo es estacionaria
# /Users/jorge/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:320: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# Estadístico ADF: -38.501528
# p-value: 0.000000
# Valor crítico:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# Rechazo Ho: La serie de tiempo es estacionaria
# /Users/jorge/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:320: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# Estadístico ADF: -36.917185
# p-value: 0.000000
# Valor crítico:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# Rechazo Ho: La serie de tiempo es estacionaria
# /Users/jorge/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:320: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# Estadístico ADF: -9.401339
# p-value: 0.000000
# Valor crítico:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# Rechazo Ho: La serie de tiempo es estacionaria
# /Users/jorge/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:320: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# Estadístico ADF: -36.680623
# p-value: 0.000000
# Valor crítico:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# Rechazo Ho: La serie de tiempo es estacionaria
# /Users/jorge/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:320: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# Estadístico ADF: -20.137157
# p-value: 0.000000
# Valor crítico:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# Rechazo Ho: La serie de tiempo es estacionaria
# /Users/jorge/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:320: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# Estadístico ADF: -6.886658
# p-value: 0.000000
# Valor crítico:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# Rechazo Ho: La serie de tiempo es estacionaria
# /Users/jorge/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:320: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# Estadístico ADF: -24.373033
# p-value: 0.000000
# Valor crítico:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# Rechazo Ho: La serie de tiempo es estacionaria
# /Users/jorge/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:320: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# Estadístico ADF: -24.284605
# p-value: 0.000000
# Valor crítico:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# Rechazo Ho: La serie de tiempo es estacionaria
# /Users/jorge/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:320: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# Estadístico ADF: -37.585398
# p-value: 0.000000
# Valor crítico:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# Rechazo Ho: La serie de tiempo es estacionaria
# /Users/jorge/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:320: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# Estadístico ADF: -36.241784
# p-value: 0.000000
# Valor crítico:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# Rechazo Ho: La serie de tiempo es estacionaria
# /Users/jorge/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:320: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# Estadístico ADF: -25.523779
# p-value: 0.000000
# Valor crítico:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# Rechazo Ho: La serie de tiempo es estacionaria
# /Users/jorge/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:320: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# Estadístico ADF: -5.404973
# p-value: 0.000003
# Valor crítico:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# Rechazo Ho: La serie de tiempo es estacionaria
# /Users/jorge/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:320: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)

# %% [markdown]
# **TODAS LAS SERIES DE TIEMPO PARA CADA UNO DE LOS BARRIOS ENTRE 2013 Y 2016 SON ESTACIONARIAS**

# %% [markdown]
# ## PRUEBAS DE CORRELACIÓN

# %%
for neighborhood_name in neighborhoods_df.index :
    nb_df = df[df.Barrio == neighborhood_name]
    h = pd.DataFrame(nb_df['FecNot'].value_counts().sort_index())
    h.columns = ['Casos']
    h.index.name = 'Fecha'
    df_zeros = assign_zeros(h)
    df_zeros.set_index('Fecha',inplace=True)
    lag_plot(df_zeros)
    plt.show()

# %% [markdown]
# ## ANÁLISIS

# %% [markdown]
# - Los datos filtrados entre 2013 y 2016 para cada barrio no están del todo correlacionados. Poseen un promedio de correlación de 0.25
